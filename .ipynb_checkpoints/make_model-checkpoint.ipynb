# %%
import pandas as pd
import numpy as np

from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from keras.layers import Input, Dense, Activation
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# tag list
tag_file=pd.read_csv("tags.csv")
tag=tag_file["tagID"]
tag=list(tag)

# user_code
user_tag_file=pd.read_csv("user_tags.csv")
company_tag_file=pd.read_csv("job_tags.csv")

# user_code 작성
list_of_user=list(set(user_tag_file["userID"]))
user_code={}
for user in list_of_user:
    user_code[user]=[0 for i in range(887)]

sizeOfUserTag=len(user_tag_file)
for i in range(sizeOfUserTag):
    tag_id_of_user=user_tag_file["tagID"][i]
    index_of_tag_user=tag.index(tag_id_of_user)  
    user_code[user_tag_file["userID"][i]][index_of_tag_user]=1
    
# company_code 작성
list_of_company=list(set(company_tag_file["jobID"]))    
company_code={}
for company in list_of_company:
    company_code[company]=[0 for i in range(887)]

sizeOfCompanyTag=len(company_tag_file)
for i in range(sizeOfCompanyTag):
    tag_id_of_company=company_tag_file["tagID"][i]
    index_of_tag_company=tag.index(tag_id_of_company)
    company_code[company_tag_file["jobID"][i]][index_of_tag_company]=1

# %%
train_file=pd.read_csv("train.csv")
size_input=len(train_file)
X_train=[]
y_train=[]

for i in range(size_input):
    userL=user_code[train_file["userID"][i]]
    companyL=company_code[train_file["jobID"][i]]
    tempL=userL+companyL
    X_train.append(tempL)
    y_train.append([train_file["applied"][i]])
    
X_train=np.array(X_train)
y_train=np.array(y_train)

# %%
def my_model(X_train,Y_train,x_degree):
    input_X = keras.Input(shape=(x_degree,),name="input_layer")
    output_model = layers.Dense(8, activation='relu',name="hidden_layer1")(input_X)
    #output_model = layers.Dense(8, activation='relu',name="hidden_layer2")(output_model)
    output_model = layers.Dense(1, activation='sigmoid',name="output_layer")(output_model)

    model = keras.Model(inputs=input_X,
                        outputs=output_model)

    model.compile(optimizer="adam",
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # starts training
    hist=model.fit(X_train,Y_train,
                   batch_size=50,
                   validation_split=0.4,
                   epochs=300,
                   verbose=1,
                   callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)],
                   shuffle=True)
    
    return hist,model

def model_summary(model):
    model.summary()
    
def grapviz(hist):
    fig, loss_ax = plt.subplots()
    acc_ax = loss_ax.twinx()
    
    loss_ax.plot(hist.history['loss'], 'y', label='train loss')
    loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

    acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
    acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')
    acc_ax.set_ylabel('accuray')

    loss_ax.legend(loc='upper left')
    acc_ax.legend(loc='lower left')
    return plt.show()

# %%
hist,model=my_model(X_train[:4000],y_train[:4000],len(X_train[0]))
# Out:
# Train on 2400 samples, validate on 1600 samples
# Epoch 1/300
# 2400/2400 [==============================] - 0s 200us/sample - loss: 0.6586 - accuracy: 0.7133 - val_loss: 0.6027 - val_accuracy: 0.8450
# Epoch 2/300
# 2400/2400 [==============================] - 0s 52us/sample - loss: 0.5578 - accuracy: 0.8604 - val_loss: 0.5228 - val_accuracy: 0.8450
# Epoch 3/300
# 2400/2400 [==============================] - 0s 50us/sample - loss: 0.4855 - accuracy: 0.8604 - val_loss: 0.4704 - val_accuracy: 0.8450
# Epoch 4/300
# 2400/2400 [==============================] - 0s 51us/sample - loss: 0.4419 - accuracy: 0.8604 - val_loss: 0.4459 - val_accuracy: 0.8450
# Epoch 5/300
# 2400/2400 [==============================] - 0s 55us/sample - loss: 0.4203 - accuracy: 0.8604 - val_loss: 0.4360 - val_accuracy: 0.8450
# Epoch 6/300
# 2400/2400 [==============================] - 0s 50us/sample - loss: 0.4077 - accuracy: 0.8604 - val_loss: 0.4301 - val_accuracy: 0.8450
# Epoch 7/300
# 2400/2400 [==============================] - 0s 54us/sample - loss: 0.3960 - accuracy: 0.8604 - val_loss: 0.4244 - val_accuracy: 0.8450
# Epoch 8/300
# 2400/2400 [==============================] - 0s 52us/sample - loss: 0.3847 - accuracy: 0.8612 - val_loss: 0.4198 - val_accuracy: 0.8456
# Epoch 9/300
# 2400/2400 [==============================] - 0s 67us/sample - loss: 0.3734 - accuracy: 0.8642 - val_loss: 0.4162 - val_accuracy: 0.8469
# Epoch 10/300
# 2400/2400 [==============================] - 0s 58us/sample - loss: 0.3643 - accuracy: 0.8692 - val_loss: 0.4137 - val_accuracy: 0.8512
# Epoch 11/300
# 2400/2400 [==============================] - 0s 52us/sample - loss: 0.3565 - accuracy: 0.8712 - val_loss: 0.4125 - val_accuracy: 0.8519
# Epoch 12/300
# 2400/2400 [==============================] - 0s 51us/sample - loss: 0.3495 - accuracy: 0.8721 - val_loss: 0.4110 - val_accuracy: 0.8525
# Epoch 13/300
# 2400/2400 [==============================] - 0s 50us/sample - loss: 0.3438 - accuracy: 0.8737 - val_loss: 0.4097 - val_accuracy: 0.8525
# Epoch 14/300
# 2400/2400 [==============================] - 0s 51us/sample - loss: 0.3383 - accuracy: 0.8771 - val_loss: 0.4097 - val_accuracy: 0.8512
# Epoch 15/300
# 2400/2400 [==============================] - 0s 51us/sample - loss: 0.3328 - accuracy: 0.8788 - val_loss: 0.4092 - val_accuracy: 0.8500
# Epoch 16/300
# 2400/2400 [==============================] - 0s 52us/sample - loss: 0.3283 - accuracy: 0.8808 - val_loss: 0.4101 - val_accuracy: 0.8512
# Epoch 17/300
# 2400/2400 [==============================] - 0s 52us/sample - loss: 0.3243 - accuracy: 0.8817 - val_loss: 0.4103 - val_accuracy: 0.8506
# Epoch 18/300
# 2400/2400 [==============================] - 0s 52us/sample - loss: 0.3201 - accuracy: 0.8850 - val_loss: 0.4089 - val_accuracy: 0.8494
# Epoch 19/300
# 2400/2400 [==============================] - 0s 53us/sample - loss: 0.3166 - accuracy: 0.8854 - val_loss: 0.4097 - val_accuracy: 0.8475
# Epoch 20/300
# 2400/2400 [==============================] - 0s 63us/sample - loss: 0.3127 - accuracy: 0.8871 - val_loss: 0.4100 - val_accuracy: 0.8494
# Epoch 21/300
# 2400/2400 [==============================] - 0s 55us/sample - loss: 0.3104 - accuracy: 0.8875 - val_loss: 0.4104 - val_accuracy: 0.8438
# Epoch 22/300
# 2400/2400 [==============================] - 0s 50us/sample - loss: 0.3065 - accuracy: 0.8875 - val_loss: 0.4114 - val_accuracy: 0.8469
# Epoch 23/300
# 2400/2400 [==============================] - 0s 50us/sample - loss: 0.3039 - accuracy: 0.8896 - val_loss: 0.4115 - val_accuracy: 0.8481
# Epoch 24/300
# 2400/2400 [==============================] - 0s 50us/sample - loss: 0.3004 - accuracy: 0.8921 - val_loss: 0.4126 - val_accuracy: 0.8456
# Epoch 25/300
# 2400/2400 [==============================] - 0s 52us/sample - loss: 0.2980 - accuracy: 0.8888 - val_loss: 0.4132 - val_accuracy: 0.8444
# Epoch 26/300
# 2400/2400 [==============================] - 0s 52us/sample - loss: 0.2951 - accuracy: 0.8921 - val_loss: 0.4138 - val_accuracy: 0.8462
# Epoch 27/300
# 2400/2400 [==============================] - 0s 51us/sample - loss: 0.2926 - accuracy: 0.8908 - val_loss: 0.4151 - val_accuracy: 0.8469
# Epoch 28/300
# 2400/2400 [==============================] - 0s 54us/sample - loss: 0.2903 - accuracy: 0.8929 - val_loss: 0.4147 - val_accuracy: 0.8450
# Epoch 29/300
# 2400/2400 [==============================] - 0s 53us/sample - loss: 0.2873 - accuracy: 0.8946 - val_loss: 0.4167 - val_accuracy: 0.8487
# Epoch 30/300
# 2400/2400 [==============================] - 0s 51us/sample - loss: 0.2854 - accuracy: 0.8950 - val_loss: 0.4172 - val_accuracy: 0.8456
# Epoch 31/300
# 2400/2400 [==============================] - 0s 61us/sample - loss: 0.2831 - accuracy: 0.8967 - val_loss: 0.4175 - val_accuracy: 0.8450
# Epoch 32/300
# 2400/2400 [==============================] - 0s 61us/sample - loss: 0.2812 - accuracy: 0.8938 - val_loss: 0.4183 - val_accuracy: 0.8406
# Epoch 33/300
# 2400/2400 [==============================] - 0s 53us/sample - loss: 0.2786 - accuracy: 0.8971 - val_loss: 0.4203 - val_accuracy: 0.8438
# Epoch 34/300
# 2400/2400 [==============================] - 0s 51us/sample - loss: 0.2765 - accuracy: 0.8975 - val_loss: 0.4197 - val_accuracy: 0.8413
# Epoch 35/300
# 2400/2400 [==============================] - 0s 53us/sample - loss: 0.2742 - accuracy: 0.8983 - val_loss: 0.4212 - val_accuracy: 0.8413
# Epoch 36/300
# 2400/2400 [==============================] - 0s 53us/sample - loss: 0.2722 - accuracy: 0.8975 - val_loss: 0.4221 - val_accuracy: 0.8419
# Epoch 37/300
# 2400/2400 [==============================] - 0s 52us/sample - loss: 0.2700 - accuracy: 0.8983 - val_loss: 0.4230 - val_accuracy: 0.8375
# Epoch 38/300
# 2400/2400 [==============================] - 0s 53us/sample - loss: 0.2685 - accuracy: 0.9017 - val_loss: 0.4232 - val_accuracy: 0.8400

# %%
model_summary(model)
grapviz(hist)
# Out:
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1774)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 8)                 14200
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 9
# =================================================================
# Total params: 14,209
# Trainable params: 14,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
score = model.evaluate(X_train[4000:], y_train[4000:])
print('test_loss: ', score[0])
print('test_acc: ', score[1])
# Out:
# 2000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# test_loss:  0.4091931290626526
# test_acc:  0.8595

# %%
model.save("donghyun_model.h5")
